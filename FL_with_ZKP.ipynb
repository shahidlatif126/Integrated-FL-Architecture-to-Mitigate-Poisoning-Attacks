# %% [markdown]
# **1. Experiments with Epsilon 0.5**

# %%
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import pickle
import os
import random

# Step 1: Load and preprocess the data
df = pd.read_csv('/content/drive/MyDrive/IDS-IOT2024/Process_1 IDS-IoT-2024.csv')

# Drop the target variable and assign features to X
X = df.iloc[:, :-1].values
y = df['Attack_Category_x'].values

# Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets for global evaluation
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Experiment setup
client_counts = [10, 25, 50, 75, 100]  # Number of clients to test
rounds = 10  # Number of federated learning rounds
privacy_budget = 0.5  # Privacy budget (epsilon)
results = []  # To store evaluation results for each client count

# Shuffle training data for IID client simulation
shuffled_indices = np.random.permutation(len(X_train_full))
X_train_shuffled = X_train_full[shuffled_indices]
y_train_shuffled = y_train_full[shuffled_indices]

# Differential Privacy - Laplace Mechanism
def apply_laplace_noise(values, epsilon, sensitivity=1.0):
    scale = sensitivity / epsilon
    noise = np.random.laplace(0, scale, size=values.shape)
    return values + noise

# Schnorr Protocol for Authentication
class SchnorrProtocol:
    def __init__(self, p, g):
        self.p = p
        self.g = g
        self.private_key = np.random.randint(1, p)
        self.public_key = pow(g, self.private_key, p)

    def generate_commitment(self):
        self.r = np.random.randint(1, self.p)
        self.R = pow(self.g, self.r, self.p)
        return self.R

    def compute_response(self, challenge):
        self.s = (self.r + challenge * self.private_key) % (self.p - 1)
        return self.s

    def verify(self, R, s, public_key, challenge):
        lhs = pow(self.g, s, self.p)
        rhs = (R * pow(public_key, challenge, self.p)) % self.p
        return lhs == rhs

# Schnorr Parameters
p = 104729
g = 2

# LightGBM parameters
lgb_params = {
    'objective': 'multiclass',
    'num_class': len(np.unique(y_encoded)),
    'boosting_type': 'gbdt',
    'metric': 'multi_logloss',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'max_depth': -1,
    'verbosity': -1
}

# Robust Aggregation (Median Aggregation)
def robust_aggregation(updates):
    """Aggregate model updates using a robust method like median aggregation."""
    return np.median(updates, axis=0)

# Experiment loop
for client_count in client_counts:
    print(f"\nRunning experiment for {client_count} clients...")

    # Step 1: Simulate clients
    client_data = []
    samples_per_client = len(X_train_shuffled) // client_count

    for i in range(client_count):
        start_idx = i * samples_per_client
        end_idx = start_idx + samples_per_client if i < client_count - 1 else len(X_train_shuffled)
        X_client = X_train_shuffled[start_idx:end_idx]
        y_client = y_train_shuffled[start_idx:end_idx]
        client_data.append((X_client, y_client))

    # Randomly assign poisoned clients
    num_data_poisoning_clients = min(2, client_count)
    num_model_poisoning_clients = min(3, client_count)
    data_poisoning_clients = random.sample(range(client_count), num_data_poisoning_clients)
    model_poisoning_clients = random.sample(
        [client for client in range(client_count) if client not in data_poisoning_clients],
        num_model_poisoning_clients,
    )

    # Reset performance tracking for the current experiment
    excluded_clients = 0
    local_accuracies = []
    global_accuracies = []
    client_auth_times = []
    client_train_times = []
    round_latencies = []
    aggregation_times = []
    communication_overheads = []

    # Reinitialize Schnorr protocols for the current number of clients
    client_protocols = [SchnorrProtocol(p, g) for _ in range(client_count)]

    # Step 2: Federated rounds
    for round_num in range(rounds):
        print(f"  Round {round_num + 1}/{rounds}")
        round_start_time = time.time()

        local_models = []
        local_predictions = []
        round_client_auth_times = []
        round_client_train_times = []
        round_comm_overhead = 0

        for client_num, (X_client, y_client) in enumerate(client_data):
            auth_start_time = time.time()
            schnorr = client_protocols[client_num]
            R = schnorr.generate_commitment()
            challenge = np.random.randint(1, p)

            # Simulate poisoning in response
            if client_num in data_poisoning_clients + model_poisoning_clients:
                response = schnorr.compute_response(challenge) + 1
            else:
                response = schnorr.compute_response(challenge)

            if not schnorr.verify(R, response, schnorr.public_key, challenge):
                print(f"    Client {client_num + 1} failed authentication and is excluded.")
                excluded_clients += 1
                continue
            auth_end_time = time.time()

            train_start_time = time.time()
            if client_num in data_poisoning_clients:
                print(f"    Simulating data poisoning on Client {client_num + 1}")
                X_client += np.random.normal(0, 0.5, X_client.shape)

            # Train local model
            train_data = lgb.Dataset(X_client, label=y_client)
            local_model = lgb.train(lgb_params, train_data, num_boost_round=20)

            if client_num in model_poisoning_clients:
                print(f"    Simulating model poisoning on Client {client_num + 1}")
                local_model.params['num_leaves'] += 5

            train_end_time = time.time()
            round_client_auth_times.append(auth_end_time - auth_start_time)
            round_client_train_times.append(train_end_time - train_start_time)

            local_model_bytes = pickle.dumps(local_model)
            round_comm_overhead += len(local_model_bytes)

            local_models.append(local_model)
            predictions = local_model.predict(X_test)
            noisy_predictions = apply_laplace_noise(predictions, epsilon=privacy_budget, sensitivity=1.0)
            local_predictions.append(noisy_predictions)

            local_pred = np.argmax(noisy_predictions, axis=1)
            local_accuracy = accuracy_score(y_test, local_pred)
            local_accuracies.append(local_accuracy)

        if local_predictions:
            aggregation_start_time = time.time()
            aggregated_predictions = robust_aggregation(local_predictions)
            y_pred_aggregated = np.argmax(aggregated_predictions, axis=1)
            global_accuracy = accuracy_score(y_test, y_pred_aggregated)
            global_accuracies.append(global_accuracy)
            aggregation_end_time = time.time()
            aggregation_times.append(aggregation_end_time - aggregation_start_time)

            aggregated_model_bytes = pickle.dumps(aggregated_predictions)
            round_comm_overhead += len(aggregated_model_bytes)

        communication_overheads.append(round_comm_overhead)
        round_latencies.append(time.time() - round_start_time)
        client_auth_times.extend(round_client_auth_times)
        client_train_times.extend(round_client_train_times)

        print(f"  Round {round_num + 1} completed with Global Accuracy: {global_accuracy:.4f}")

    # Save global model
    with open(f"global_model_{client_count}.pkl", "wb") as f:
        pickle.dump(local_models[0], f)

    global_model_size = os.path.getsize(f"global_model_{client_count}.pkl") / (1024 ** 2)  # in MB
    results.append({
        'clients': client_count,
        'avg_global_accuracy': np.mean(global_accuracies),
        'avg_local_accuracy': np.mean(local_accuracies),
        'avg_train_time': np.mean(client_train_times),
        'avg_auth_time': np.mean(client_auth_times),
        'avg_round_latency': np.mean(round_latencies),
        'avg_aggregation_time': np.mean(aggregation_times),
        'avg_comm_overhead': np.mean(communication_overheads) / (1024 ** 2),
        'global_model_size': global_model_size,
    })

# Print all results
print("\nExperiment Results:")
for result in results:
    print(f"Clients: {result['clients']}, "
          f"Avg Global Accuracy: {result['avg_global_accuracy']:.5f}, "
          f"Avg Local Accuracy: {result['avg_local_accuracy']:.5f}, "
          f"Avg Train Time: {result['avg_train_time']:.5f}s, "
          f"Avg Auth Time: {result['avg_auth_time']:.5f}s, "
          f"Avg Round Latency: {result['avg_round_latency']:.5f}s, "
          f"Avg Aggregation Time: {result['avg_aggregation_time']:.5f}s, "
          f"Avg Comm Overhead: {result['avg_comm_overhead']:.5f}MB, "
          f"Global Model Size: {result['global_model_size']:.5f}MB")
# Out:
# Running experiment for 10 clients...
#   Round 1/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.3547
#   Round 2/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.3611
#   Round 3/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.3633
#   Round 4/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.3624
#   Round 5/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.3596
#   Round 6/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.3648
#   Round 7/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.3663
#   Round 8/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.3593
#   Round 9/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.3651
#   Round 10/10
#     Client 2 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.3633
#
# Running experiment for 25 clients...
#   Round 1/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.6851
#   Round 2/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.6919
#   Round 3/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.6856
#   Round 4/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.6846
#   Round 5/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.6873
#   Round 6/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.6863
#   Round 7/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.6843
#   Round 8/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.6835
#   Round 9/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.6871
#   Round 10/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.6888
#
# Running experiment for 50 clients...
#   Round 1/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.8856
#   Round 2/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.8848
#   Round 3/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.8892
#   Round 4/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.8832
#   Round 5/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.8823
#   Round 6/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.8856
#   Round 7/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.8820
#   Round 8/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.8880
#   Round 9/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.8835
#   Round 10/10
#     Client 11 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 30 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.8796
#
# Running experiment for 75 clients...
#   Round 1/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9468
#   Round 2/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9481
#   Round 3/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9450
#   Round 4/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9474
#   Round 5/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9467
#   Round 6/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9466
#   Round 7/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9452
#   Round 8/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9478
#   Round 9/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9487
#   Round 10/10
#     Client 11 failed authentication and is excluded.
#     Client 40 failed authentication and is excluded.
#     Client 61 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9459
#
# Running experiment for 100 clients...
#   Round 1/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9614
#   Round 2/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9643
#   Round 3/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9639
#   Round 4/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9645
#   Round 5/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9639
#   Round 6/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9630
#   Round 7/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9637
#   Round 8/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9638
#   Round 9/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9627
#   Round 10/10
#     Client 19 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 52 failed authentication and is excluded.
#     Client 53 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9634
#
# Experiment Results:
# Clients: 10, Avg Global Accuracy: 0.36201, Avg Local Accuracy: 0.22369, Avg Train Time: 0.40533s, Avg Auth Time: 0.00005s, Avg Round Latency: 2.66028s, Avg Aggregation Time: 0.01835s, Avg Comm Overhead: 3.36604MB, Global Model Size: 0.46728MB
# Clients: 25, Avg Global Accuracy: 0.68646, Avg Local Accuracy: 0.22316, Avg Train Time: 0.25257s, Avg Auth Time: 0.00005s, Avg Round Latency: 7.66626s, Avg Aggregation Time: 0.07490s, Avg Comm Overhead: 10.33470MB, Global Model Size: 0.46430MB
# Clients: 50, Avg Global Accuracy: 0.88438, Avg Local Accuracy: 0.22210, Avg Train Time: 0.18004s, Avg Auth Time: 0.00005s, Avg Round Latency: 14.31665s, Avg Aggregation Time: 0.13992s, Avg Comm Overhead: 21.89211MB, Global Model Size: 0.46285MB
# Clients: 75, Avg Global Accuracy: 0.94681, Avg Local Accuracy: 0.22122, Avg Train Time: 0.13958s, Avg Auth Time: 0.00006s, Avg Round Latency: 19.56568s, Avg Aggregation Time: 0.21254s, Avg Comm Overhead: 33.23931MB, Global Model Size: 0.45990MB
# Clients: 100, Avg Global Accuracy: 0.96346, Avg Local Accuracy: 0.22041, Avg Train Time: 0.10580s, Avg Auth Time: 0.00006s, Avg Round Latency: 22.55445s, Avg Aggregation Time: 0.27630s, Avg Comm Overhead: 38.50472MB, Global Model Size: 0.39163MB

# %% [markdown]
# **2. Experiments with Epsilon 0.8**

# %%
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import pickle
import os
import random

# Step 1: Load and preprocess the data
df = pd.read_csv('/content/drive/MyDrive/IDS-IOT2024/Process_1 IDS-IoT-2024.csv')

# Drop the target variable and assign features to X
X = df.iloc[:, :-1].values
y = df['Attack_Category_x'].values

# Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets for global evaluation
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Experiment setup
client_counts = [10, 25, 50, 75, 100]  # Number of clients to test
rounds = 10  # Number of federated learning rounds
privacy_budget = 0.8  # Privacy budget (epsilon)
results = []  # To store evaluation results for each client count

# Shuffle training data for IID client simulation
shuffled_indices = np.random.permutation(len(X_train_full))
X_train_shuffled = X_train_full[shuffled_indices]
y_train_shuffled = y_train_full[shuffled_indices]

# Differential Privacy - Laplace Mechanism
def apply_laplace_noise(values, epsilon, sensitivity=1.0):
    scale = sensitivity / epsilon
    noise = np.random.laplace(0, scale, size=values.shape)
    return values + noise

# Schnorr Protocol for Authentication
class SchnorrProtocol:
    def __init__(self, p, g):
        self.p = p
        self.g = g
        self.private_key = np.random.randint(1, p)
        self.public_key = pow(g, self.private_key, p)

    def generate_commitment(self):
        self.r = np.random.randint(1, self.p)
        self.R = pow(self.g, self.r, self.p)
        return self.R

    def compute_response(self, challenge):
        self.s = (self.r + challenge * self.private_key) % (self.p - 1)
        return self.s

    def verify(self, R, s, public_key, challenge):
        lhs = pow(self.g, s, self.p)
        rhs = (R * pow(public_key, challenge, self.p)) % self.p
        return lhs == rhs

# Schnorr Parameters
p = 104729
g = 2

# LightGBM parameters
lgb_params = {
    'objective': 'multiclass',
    'num_class': len(np.unique(y_encoded)),
    'boosting_type': 'gbdt',
    'metric': 'multi_logloss',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'max_depth': -1,
    'verbosity': -1
}

# Robust Aggregation (Median Aggregation)
def robust_aggregation(updates):
    """Aggregate model updates using a robust method like median aggregation."""
    return np.median(updates, axis=0)

# Experiment loop
for client_count in client_counts:
    print(f"\nRunning experiment for {client_count} clients...")

    # Step 1: Simulate clients
    client_data = []
    samples_per_client = len(X_train_shuffled) // client_count

    for i in range(client_count):
        start_idx = i * samples_per_client
        end_idx = start_idx + samples_per_client if i < client_count - 1 else len(X_train_shuffled)
        X_client = X_train_shuffled[start_idx:end_idx]
        y_client = y_train_shuffled[start_idx:end_idx]
        client_data.append((X_client, y_client))

    # Randomly assign poisoned clients
    num_data_poisoning_clients = min(2, client_count)
    num_model_poisoning_clients = min(3, client_count)
    data_poisoning_clients = random.sample(range(client_count), num_data_poisoning_clients)
    model_poisoning_clients = random.sample(
        [client for client in range(client_count) if client not in data_poisoning_clients],
        num_model_poisoning_clients,
    )

    # Reset performance tracking for the current experiment
    excluded_clients = 0
    local_accuracies = []
    global_accuracies = []
    client_auth_times = []
    client_train_times = []
    round_latencies = []
    aggregation_times = []
    communication_overheads = []

    # Reinitialize Schnorr protocols for the current number of clients
    client_protocols = [SchnorrProtocol(p, g) for _ in range(client_count)]

    # Step 2: Federated rounds
    for round_num in range(rounds):
        print(f"  Round {round_num + 1}/{rounds}")
        round_start_time = time.time()

        local_models = []
        local_predictions = []
        round_client_auth_times = []
        round_client_train_times = []
        round_comm_overhead = 0

        for client_num, (X_client, y_client) in enumerate(client_data):
            auth_start_time = time.time()
            schnorr = client_protocols[client_num]
            R = schnorr.generate_commitment()
            challenge = np.random.randint(1, p)

            # Simulate poisoning in response
            if client_num in data_poisoning_clients + model_poisoning_clients:
                response = schnorr.compute_response(challenge) + 1
            else:
                response = schnorr.compute_response(challenge)

            if not schnorr.verify(R, response, schnorr.public_key, challenge):
                print(f"    Client {client_num + 1} failed authentication and is excluded.")
                excluded_clients += 1
                continue
            auth_end_time = time.time()

            train_start_time = time.time()
            if client_num in data_poisoning_clients:
                print(f"    Simulating data poisoning on Client {client_num + 1}")
                X_client += np.random.normal(0, 0.5, X_client.shape)

            # Train local model
            train_data = lgb.Dataset(X_client, label=y_client)
            local_model = lgb.train(lgb_params, train_data, num_boost_round=20)

            if client_num in model_poisoning_clients:
                print(f"    Simulating model poisoning on Client {client_num + 1}")
                local_model.params['num_leaves'] += 5

            train_end_time = time.time()
            round_client_auth_times.append(auth_end_time - auth_start_time)
            round_client_train_times.append(train_end_time - train_start_time)

            local_model_bytes = pickle.dumps(local_model)
            round_comm_overhead += len(local_model_bytes)

            local_models.append(local_model)
            predictions = local_model.predict(X_test)
            noisy_predictions = apply_laplace_noise(predictions, epsilon=privacy_budget, sensitivity=1.0)
            local_predictions.append(noisy_predictions)

            local_pred = np.argmax(noisy_predictions, axis=1)
            local_accuracy = accuracy_score(y_test, local_pred)
            local_accuracies.append(local_accuracy)

        if local_predictions:
            aggregation_start_time = time.time()
            aggregated_predictions = robust_aggregation(local_predictions)
            y_pred_aggregated = np.argmax(aggregated_predictions, axis=1)
            global_accuracy = accuracy_score(y_test, y_pred_aggregated)
            global_accuracies.append(global_accuracy)
            aggregation_end_time = time.time()
            aggregation_times.append(aggregation_end_time - aggregation_start_time)

            aggregated_model_bytes = pickle.dumps(aggregated_predictions)
            round_comm_overhead += len(aggregated_model_bytes)

        communication_overheads.append(round_comm_overhead)
        round_latencies.append(time.time() - round_start_time)
        client_auth_times.extend(round_client_auth_times)
        client_train_times.extend(round_client_train_times)

        print(f"  Round {round_num + 1} completed with Global Accuracy: {global_accuracy:.4f}")

    # Save global model
    with open(f"global_model_{client_count}.pkl", "wb") as f:
        pickle.dump(local_models[0], f)

    global_model_size = os.path.getsize(f"global_model_{client_count}.pkl") / (1024 ** 2)  # in MB
    results.append({
        'clients': client_count,
        'avg_global_accuracy': np.mean(global_accuracies),
        'avg_local_accuracy': np.mean(local_accuracies),
        'avg_train_time': np.mean(client_train_times),
        'avg_auth_time': np.mean(client_auth_times),
        'avg_round_latency': np.mean(round_latencies),
        'avg_aggregation_time': np.mean(aggregation_times),
        'avg_comm_overhead': np.mean(communication_overheads) / (1024 ** 2),
        'global_model_size': global_model_size,
    })

# Print all results
print("\nExperiment Results:")
for result in results:
    print(f"Clients: {result['clients']}, "
          f"Avg Global Accuracy: {result['avg_global_accuracy']:.5f}, "
          f"Avg Local Accuracy: {result['avg_local_accuracy']:.5f}, "
          f"Avg Train Time: {result['avg_train_time']:.5f}s, "
          f"Avg Auth Time: {result['avg_auth_time']:.5f}s, "
          f"Avg Round Latency: {result['avg_round_latency']:.5f}s, "
          f"Avg Aggregation Time: {result['avg_aggregation_time']:.5f}s, "
          f"Avg Comm Overhead: {result['avg_comm_overhead']:.5f}MB, "
          f"Global Model Size: {result['global_model_size']:.5f}MB")
# Out:
# Running experiment for 10 clients...
#   Round 1/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.5193
#   Round 2/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.5265
#   Round 3/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.5239
#   Round 4/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.5165
#   Round 5/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.5211
#   Round 6/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.5236
#   Round 7/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.5245
#   Round 8/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.5290
#   Round 9/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.5283
#   Round 10/10
#     Client 3 failed authentication and is excluded.
#     Client 4 failed authentication and is excluded.
#     Client 5 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.5277
#
# Running experiment for 25 clients...
#   Round 1/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9010
#   Round 2/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.8994
#   Round 3/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9030
#   Round 4/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9003
#   Round 5/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9030
#   Round 6/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9022
#   Round 7/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9010
#   Round 8/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.8973
#   Round 9/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.8979
#   Round 10/10
#     Client 4 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9006
#
# Running experiment for 50 clients...
#   Round 1/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9753
#   Round 2/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9761
#   Round 3/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9759
#   Round 4/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9757
#   Round 5/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9762
#   Round 6/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9763
#   Round 7/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9775
#   Round 8/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9768
#   Round 9/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9766
#   Round 10/10
#     Client 22 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#     Client 41 failed authentication and is excluded.
#     Client 42 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9771
#
# Running experiment for 75 clients...
#   Round 1/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9822
#   Round 2/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9819
#   Round 3/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9808
#   Round 4/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9811
#   Round 5/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9805
#   Round 6/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9821
#   Round 7/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9816
#   Round 8/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9814
#   Round 9/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9814
#   Round 10/10
#     Client 1 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9817
#
# Running experiment for 100 clients...
#   Round 1/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9779
#   Round 2/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9786
#   Round 3/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9786
#   Round 4/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9784
#   Round 5/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9777
#   Round 6/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9785
#   Round 7/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9780
#   Round 8/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9774
#   Round 9/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9780
#   Round 10/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 54 failed authentication and is excluded.
#     Client 84 failed authentication and is excluded.
#     Client 96 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9774
#
# Experiment Results:
# Clients: 10, Avg Global Accuracy: 0.52404, Avg Local Accuracy: 0.28442, Avg Train Time: 0.55992s, Avg Auth Time: 0.00005s, Avg Round Latency: 3.47857s, Avg Aggregation Time: 0.02335s, Avg Comm Overhead: 3.36419MB, Global Model Size: 0.46655MB
# Clients: 25, Avg Global Accuracy: 0.90056, Avg Local Accuracy: 0.28343, Avg Train Time: 0.32994s, Avg Auth Time: 0.00005s, Avg Round Latency: 9.37469s, Avg Aggregation Time: 0.08403s, Avg Comm Overhead: 10.33019MB, Global Model Size: 0.46430MB
# Clients: 50, Avg Global Accuracy: 0.97635, Avg Local Accuracy: 0.28216, Avg Train Time: 0.18018s, Avg Auth Time: 0.00005s, Avg Round Latency: 14.32915s, Avg Aggregation Time: 0.14874s, Avg Comm Overhead: 21.88960MB, Global Model Size: 0.46324MB
# Clients: 75, Avg Global Accuracy: 0.98147, Avg Local Accuracy: 0.28052, Avg Train Time: 0.14091s, Avg Auth Time: 0.00006s, Avg Round Latency: 19.69004s, Avg Aggregation Time: 0.21209s, Avg Comm Overhead: 33.24578MB, Global Model Size: 0.46052MB
# Clients: 100, Avg Global Accuracy: 0.97805, Avg Local Accuracy: 0.27891, Avg Train Time: 0.10532s, Avg Auth Time: 0.00005s, Avg Round Latency: 22.33561s, Avg Aggregation Time: 0.27552s, Avg Comm Overhead: 38.60259MB, Global Model Size: 0.39497MB

# %% [markdown]
# **3. Experiments with Epsilon 1.0**

# %%
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import pickle
import os
import random

# Step 1: Load and preprocess the data
df = pd.read_csv('/content/drive/MyDrive/IDS-IOT2024/Process_1 IDS-IoT-2024.csv')

# Drop the target variable and assign features to X
X = df.iloc[:, :-1].values
y = df['Attack_Category_x'].values

# Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets for global evaluation
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Experiment setup
client_counts = [10, 25, 50, 75, 100]  # Number of clients to test
rounds = 10  # Number of federated learning rounds
privacy_budget = 1.0  # Privacy budget (epsilon)
results = []  # To store evaluation results for each client count

# Shuffle training data for IID client simulation
shuffled_indices = np.random.permutation(len(X_train_full))
X_train_shuffled = X_train_full[shuffled_indices]
y_train_shuffled = y_train_full[shuffled_indices]

# Differential Privacy - Laplace Mechanism
def apply_laplace_noise(values, epsilon, sensitivity=1.0):
    scale = sensitivity / epsilon
    noise = np.random.laplace(0, scale, size=values.shape)
    return values + noise

# Schnorr Protocol for Authentication
class SchnorrProtocol:
    def __init__(self, p, g):
        self.p = p
        self.g = g
        self.private_key = np.random.randint(1, p)
        self.public_key = pow(g, self.private_key, p)

    def generate_commitment(self):
        self.r = np.random.randint(1, self.p)
        self.R = pow(self.g, self.r, self.p)
        return self.R

    def compute_response(self, challenge):
        self.s = (self.r + challenge * self.private_key) % (self.p - 1)
        return self.s

    def verify(self, R, s, public_key, challenge):
        lhs = pow(self.g, s, self.p)
        rhs = (R * pow(public_key, challenge, self.p)) % self.p
        return lhs == rhs

# Schnorr Parameters
p = 104729
g = 2

# LightGBM parameters
lgb_params = {
    'objective': 'multiclass',
    'num_class': len(np.unique(y_encoded)),
    'boosting_type': 'gbdt',
    'metric': 'multi_logloss',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'max_depth': -1,
    'verbosity': -1
}

# Robust Aggregation (Median Aggregation)
def robust_aggregation(updates):
    """Aggregate model updates using a robust method like median aggregation."""
    return np.median(updates, axis=0)

# Experiment loop
for client_count in client_counts:
    print(f"\nRunning experiment for {client_count} clients...")

    # Step 1: Simulate clients
    client_data = []
    samples_per_client = len(X_train_shuffled) // client_count

    for i in range(client_count):
        start_idx = i * samples_per_client
        end_idx = start_idx + samples_per_client if i < client_count - 1 else len(X_train_shuffled)
        X_client = X_train_shuffled[start_idx:end_idx]
        y_client = y_train_shuffled[start_idx:end_idx]
        client_data.append((X_client, y_client))

    # Randomly assign poisoned clients
    num_data_poisoning_clients = min(2, client_count)
    num_model_poisoning_clients = min(3, client_count)
    data_poisoning_clients = random.sample(range(client_count), num_data_poisoning_clients)
    model_poisoning_clients = random.sample(
        [client for client in range(client_count) if client not in data_poisoning_clients],
        num_model_poisoning_clients,
    )

    # Reset performance tracking for the current experiment
    excluded_clients = 0
    local_accuracies = []
    global_accuracies = []
    client_auth_times = []
    client_train_times = []
    round_latencies = []
    aggregation_times = []
    communication_overheads = []

    # Reinitialize Schnorr protocols for the current number of clients
    client_protocols = [SchnorrProtocol(p, g) for _ in range(client_count)]

    # Step 2: Federated rounds
    for round_num in range(rounds):
        print(f"  Round {round_num + 1}/{rounds}")
        round_start_time = time.time()

        local_models = []
        local_predictions = []
        round_client_auth_times = []
        round_client_train_times = []
        round_comm_overhead = 0

        for client_num, (X_client, y_client) in enumerate(client_data):
            auth_start_time = time.time()
            schnorr = client_protocols[client_num]
            R = schnorr.generate_commitment()
            challenge = np.random.randint(1, p)

            # Simulate poisoning in response
            if client_num in data_poisoning_clients + model_poisoning_clients:
                response = schnorr.compute_response(challenge) + 1
            else:
                response = schnorr.compute_response(challenge)

            if not schnorr.verify(R, response, schnorr.public_key, challenge):
                print(f"    Client {client_num + 1} failed authentication and is excluded.")
                excluded_clients += 1
                continue
            auth_end_time = time.time()

            train_start_time = time.time()
            if client_num in data_poisoning_clients:
                print(f"    Simulating data poisoning on Client {client_num + 1}")
                X_client += np.random.normal(0, 0.5, X_client.shape)

            # Train local model
            train_data = lgb.Dataset(X_client, label=y_client)
            local_model = lgb.train(lgb_params, train_data, num_boost_round=20)

            if client_num in model_poisoning_clients:
                print(f"    Simulating model poisoning on Client {client_num + 1}")
                local_model.params['num_leaves'] += 5

            train_end_time = time.time()
            round_client_auth_times.append(auth_end_time - auth_start_time)
            round_client_train_times.append(train_end_time - train_start_time)

            local_model_bytes = pickle.dumps(local_model)
            round_comm_overhead += len(local_model_bytes)

            local_models.append(local_model)
            predictions = local_model.predict(X_test)
            noisy_predictions = apply_laplace_noise(predictions, epsilon=privacy_budget, sensitivity=1.0)
            local_predictions.append(noisy_predictions)

            local_pred = np.argmax(noisy_predictions, axis=1)
            local_accuracy = accuracy_score(y_test, local_pred)
            local_accuracies.append(local_accuracy)

        if local_predictions:
            aggregation_start_time = time.time()
            aggregated_predictions = robust_aggregation(local_predictions)
            y_pred_aggregated = np.argmax(aggregated_predictions, axis=1)
            global_accuracy = accuracy_score(y_test, y_pred_aggregated)
            global_accuracies.append(global_accuracy)
            aggregation_end_time = time.time()
            aggregation_times.append(aggregation_end_time - aggregation_start_time)

            aggregated_model_bytes = pickle.dumps(aggregated_predictions)
            round_comm_overhead += len(aggregated_model_bytes)

        communication_overheads.append(round_comm_overhead)
        round_latencies.append(time.time() - round_start_time)
        client_auth_times.extend(round_client_auth_times)
        client_train_times.extend(round_client_train_times)

        print(f"  Round {round_num + 1} completed with Global Accuracy: {global_accuracy:.4f}")

    # Save global model
    with open(f"global_model_{client_count}.pkl", "wb") as f:
        pickle.dump(local_models[0], f)

    global_model_size = os.path.getsize(f"global_model_{client_count}.pkl") / (1024 ** 2)  # in MB
    results.append({
        'clients': client_count,
        'avg_global_accuracy': np.mean(global_accuracies),
        'avg_local_accuracy': np.mean(local_accuracies),
        'avg_train_time': np.mean(client_train_times),
        'avg_auth_time': np.mean(client_auth_times),
        'avg_round_latency': np.mean(round_latencies),
        'avg_aggregation_time': np.mean(aggregation_times),
        'avg_comm_overhead': np.mean(communication_overheads) / (1024 ** 2),
        'global_model_size': global_model_size,
    })

# Print all results
print("\nExperiment Results:")
for result in results:
    print(f"Clients: {result['clients']}, "
          f"Avg Global Accuracy: {result['avg_global_accuracy']:.5f}, "
          f"Avg Local Accuracy: {result['avg_local_accuracy']:.5f}, "
          f"Avg Train Time: {result['avg_train_time']:.5f}s, "
          f"Avg Auth Time: {result['avg_auth_time']:.5f}s, "
          f"Avg Round Latency: {result['avg_round_latency']:.5f}s, "
          f"Avg Aggregation Time: {result['avg_aggregation_time']:.5f}s, "
          f"Avg Comm Overhead: {result['avg_comm_overhead']:.5f}MB, "
          f"Global Model Size: {result['global_model_size']:.5f}MB")
# Out:
# Running experiment for 10 clients...
#   Round 1/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.6307
#   Round 2/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.6319
#   Round 3/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.6311
#   Round 4/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.6314
#   Round 5/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.6284
#   Round 6/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.6306
#   Round 7/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.6328
#   Round 8/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.6352
#   Round 9/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.6354
#   Round 10/10
#     Client 2 failed authentication and is excluded.
#     Client 6 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.6283
#
# Running experiment for 25 clients...
#   Round 1/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9560
#   Round 2/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9578
#   Round 3/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9580
#   Round 4/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9574
#   Round 5/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9539
#   Round 6/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9556
#   Round 7/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9563
#   Round 8/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9604
#   Round 9/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9581
#   Round 10/10
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9579
#
# Running experiment for 50 clients...
#   Round 1/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9851
#   Round 2/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9844
#   Round 3/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9857
#   Round 4/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9840
#   Round 5/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9846
#   Round 6/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9847
#   Round 7/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9842
#   Round 8/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9845
#   Round 9/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9840
#   Round 10/10
#     Client 14 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 25 failed authentication and is excluded.
#     Client 32 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9843
#
# Running experiment for 75 clients...
#   Round 1/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9822
#   Round 2/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9822
#   Round 3/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9833
#   Round 4/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9823
#   Round 5/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9828
#   Round 6/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9826
#   Round 7/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9832
#   Round 8/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9829
#   Round 9/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9827
#   Round 10/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 44 failed authentication and is excluded.
#     Client 72 failed authentication and is excluded.
#     Client 75 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9833
#
# Running experiment for 100 clients...
#   Round 1/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9793
#   Round 2/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9788
#   Round 3/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9783
#   Round 4/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9787
#   Round 5/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9785
#   Round 6/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9792
#   Round 7/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9790
#   Round 8/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9786
#   Round 9/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9785
#   Round 10/10
#     Client 11 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9788
#
# Experiment Results:
# Clients: 10, Avg Global Accuracy: 0.63158, Avg Local Accuracy: 0.33126, Avg Train Time: 0.38027s, Avg Auth Time: 0.00005s, Avg Round Latency: 2.51470s, Avg Aggregation Time: 0.01811s, Avg Comm Overhead: 3.36938MB, Global Model Size: 0.46941MB
# Clients: 25, Avg Global Accuracy: 0.95713, Avg Local Accuracy: 0.32844, Avg Train Time: 0.23173s, Avg Auth Time: 0.00005s, Avg Round Latency: 7.19496s, Avg Aggregation Time: 0.06355s, Avg Comm Overhead: 10.33785MB, Global Model Size: 0.46591MB
# Clients: 50, Avg Global Accuracy: 0.98454, Avg Local Accuracy: 0.32623, Avg Train Time: 0.17786s, Avg Auth Time: 0.00005s, Avg Round Latency: 14.17875s, Avg Aggregation Time: 0.17525s, Avg Comm Overhead: 21.89734MB, Global Model Size: 0.46395MB
# Clients: 75, Avg Global Accuracy: 0.98273, Avg Local Accuracy: 0.32381, Avg Train Time: 0.14149s, Avg Auth Time: 0.00005s, Avg Round Latency: 19.47738s, Avg Aggregation Time: 0.20464s, Avg Comm Overhead: 33.23680MB, Global Model Size: 0.45931MB
# Clients: 100, Avg Global Accuracy: 0.97876, Avg Local Accuracy: 0.32189, Avg Train Time: 0.10431s, Avg Auth Time: 0.00005s, Avg Round Latency: 22.25436s, Avg Aggregation Time: 0.28298s, Avg Comm Overhead: 38.55691MB, Global Model Size: 0.37596MB

# %% [markdown]
# **4. Experiments with Epsilon 1.3**

# %%
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import pickle
import os
import random

# Step 1: Load and preprocess the data
df = pd.read_csv('/content/drive/MyDrive/IDS-IOT2024/Process_1 IDS-IoT-2024.csv')

# Drop the target variable and assign features to X
X = df.iloc[:, :-1].values
y = df['Attack_Category_x'].values

# Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets for global evaluation
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Experiment setup
client_counts = [10, 25, 50, 75, 100]  # Number of clients to test
rounds = 10  # Number of federated learning rounds
privacy_budget = 1.3  # Privacy budget (epsilon)
results = []  # To store evaluation results for each client count

# Shuffle training data for IID client simulation
shuffled_indices = np.random.permutation(len(X_train_full))
X_train_shuffled = X_train_full[shuffled_indices]
y_train_shuffled = y_train_full[shuffled_indices]

# Differential Privacy - Laplace Mechanism
def apply_laplace_noise(values, epsilon, sensitivity=1.0):
    scale = sensitivity / epsilon
    noise = np.random.laplace(0, scale, size=values.shape)
    return values + noise

# Schnorr Protocol for Authentication
class SchnorrProtocol:
    def __init__(self, p, g):
        self.p = p
        self.g = g
        self.private_key = np.random.randint(1, p)
        self.public_key = pow(g, self.private_key, p)

    def generate_commitment(self):
        self.r = np.random.randint(1, self.p)
        self.R = pow(self.g, self.r, self.p)
        return self.R

    def compute_response(self, challenge):
        self.s = (self.r + challenge * self.private_key) % (self.p - 1)
        return self.s

    def verify(self, R, s, public_key, challenge):
        lhs = pow(self.g, s, self.p)
        rhs = (R * pow(public_key, challenge, self.p)) % self.p
        return lhs == rhs

# Schnorr Parameters
p = 104729
g = 2

# LightGBM parameters
lgb_params = {
    'objective': 'multiclass',
    'num_class': len(np.unique(y_encoded)),
    'boosting_type': 'gbdt',
    'metric': 'multi_logloss',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'max_depth': -1,
    'verbosity': -1
}

# Robust Aggregation (Median Aggregation)
def robust_aggregation(updates):
    """Aggregate model updates using a robust method like median aggregation."""
    return np.median(updates, axis=0)

# Experiment loop
for client_count in client_counts:
    print(f"\nRunning experiment for {client_count} clients...")

    # Step 1: Simulate clients
    client_data = []
    samples_per_client = len(X_train_shuffled) // client_count

    for i in range(client_count):
        start_idx = i * samples_per_client
        end_idx = start_idx + samples_per_client if i < client_count - 1 else len(X_train_shuffled)
        X_client = X_train_shuffled[start_idx:end_idx]
        y_client = y_train_shuffled[start_idx:end_idx]
        client_data.append((X_client, y_client))

    # Randomly assign poisoned clients
    num_data_poisoning_clients = min(2, client_count)
    num_model_poisoning_clients = min(3, client_count)
    data_poisoning_clients = random.sample(range(client_count), num_data_poisoning_clients)
    model_poisoning_clients = random.sample(
        [client for client in range(client_count) if client not in data_poisoning_clients],
        num_model_poisoning_clients,
    )

    # Reset performance tracking for the current experiment
    excluded_clients = 0
    local_accuracies = []
    global_accuracies = []
    client_auth_times = []
    client_train_times = []
    round_latencies = []
    aggregation_times = []
    communication_overheads = []

    # Reinitialize Schnorr protocols for the current number of clients
    client_protocols = [SchnorrProtocol(p, g) for _ in range(client_count)]

    # Step 2: Federated rounds
    for round_num in range(rounds):
        print(f"  Round {round_num + 1}/{rounds}")
        round_start_time = time.time()

        local_models = []
        local_predictions = []
        round_client_auth_times = []
        round_client_train_times = []
        round_comm_overhead = 0

        for client_num, (X_client, y_client) in enumerate(client_data):
            auth_start_time = time.time()
            schnorr = client_protocols[client_num]
            R = schnorr.generate_commitment()
            challenge = np.random.randint(1, p)

            # Simulate poisoning in response
            if client_num in data_poisoning_clients + model_poisoning_clients:
                response = schnorr.compute_response(challenge) + 1
            else:
                response = schnorr.compute_response(challenge)

            if not schnorr.verify(R, response, schnorr.public_key, challenge):
                print(f"    Client {client_num + 1} failed authentication and is excluded.")
                excluded_clients += 1
                continue
            auth_end_time = time.time()

            train_start_time = time.time()
            if client_num in data_poisoning_clients:
                print(f"    Simulating data poisoning on Client {client_num + 1}")
                X_client += np.random.normal(0, 0.5, X_client.shape)

            # Train local model
            train_data = lgb.Dataset(X_client, label=y_client)
            local_model = lgb.train(lgb_params, train_data, num_boost_round=20)

            if client_num in model_poisoning_clients:
                print(f"    Simulating model poisoning on Client {client_num + 1}")
                local_model.params['num_leaves'] += 5

            train_end_time = time.time()
            round_client_auth_times.append(auth_end_time - auth_start_time)
            round_client_train_times.append(train_end_time - train_start_time)

            local_model_bytes = pickle.dumps(local_model)
            round_comm_overhead += len(local_model_bytes)

            local_models.append(local_model)
            predictions = local_model.predict(X_test)
            noisy_predictions = apply_laplace_noise(predictions, epsilon=privacy_budget, sensitivity=1.0)
            local_predictions.append(noisy_predictions)

            local_pred = np.argmax(noisy_predictions, axis=1)
            local_accuracy = accuracy_score(y_test, local_pred)
            local_accuracies.append(local_accuracy)

        if local_predictions:
            aggregation_start_time = time.time()
            aggregated_predictions = robust_aggregation(local_predictions)
            y_pred_aggregated = np.argmax(aggregated_predictions, axis=1)
            global_accuracy = accuracy_score(y_test, y_pred_aggregated)
            global_accuracies.append(global_accuracy)
            aggregation_end_time = time.time()
            aggregation_times.append(aggregation_end_time - aggregation_start_time)

            aggregated_model_bytes = pickle.dumps(aggregated_predictions)
            round_comm_overhead += len(aggregated_model_bytes)

        communication_overheads.append(round_comm_overhead)
        round_latencies.append(time.time() - round_start_time)
        client_auth_times.extend(round_client_auth_times)
        client_train_times.extend(round_client_train_times)

        print(f"  Round {round_num + 1} completed with Global Accuracy: {global_accuracy:.4f}")

    # Save global model
    with open(f"global_model_{client_count}.pkl", "wb") as f:
        pickle.dump(local_models[0], f)

    global_model_size = os.path.getsize(f"global_model_{client_count}.pkl") / (1024 ** 2)  # in MB
    results.append({
        'clients': client_count,
        'avg_global_accuracy': np.mean(global_accuracies),
        'avg_local_accuracy': np.mean(local_accuracies),
        'avg_train_time': np.mean(client_train_times),
        'avg_auth_time': np.mean(client_auth_times),
        'avg_round_latency': np.mean(round_latencies),
        'avg_aggregation_time': np.mean(aggregation_times),
        'avg_comm_overhead': np.mean(communication_overheads) / (1024 ** 2),
        'global_model_size': global_model_size,
    })

# Print all results
print("\nExperiment Results:")
for result in results:
    print(f"Clients: {result['clients']}, "
          f"Avg Global Accuracy: {result['avg_global_accuracy']:.5f}, "
          f"Avg Local Accuracy: {result['avg_local_accuracy']:.5f}, "
          f"Avg Train Time: {result['avg_train_time']:.5f}s, "
          f"Avg Auth Time: {result['avg_auth_time']:.5f}s, "
          f"Avg Round Latency: {result['avg_round_latency']:.5f}s, "
          f"Avg Aggregation Time: {result['avg_aggregation_time']:.5f}s, "
          f"Avg Comm Overhead: {result['avg_comm_overhead']:.5f}MB, "
          f"Global Model Size: {result['global_model_size']:.5f}MB")
# Out:
# Running experiment for 10 clients...
#   Round 1/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.7595
#   Round 2/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.7633
#   Round 3/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.7653
#   Round 4/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.7632
#   Round 5/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.7641
#   Round 6/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.7662
#   Round 7/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.7669
#   Round 8/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.7589
#   Round 9/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.7624
#   Round 10/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.7619
#
# Running experiment for 25 clients...
#   Round 1/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9837
#   Round 2/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9834
#   Round 3/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9825
#   Round 4/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9831
#   Round 5/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9827
#   Round 6/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9826
#   Round 7/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9837
#   Round 8/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9819
#   Round 9/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9833
#   Round 10/10
#     Client 14 failed authentication and is excluded.
#     Client 18 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 23 failed authentication and is excluded.
#     Client 24 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9836
#
# Running experiment for 50 clients...
#   Round 1/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9858
#   Round 2/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9863
#   Round 3/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9855
#   Round 4/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9859
#   Round 5/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9862
#   Round 6/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9857
#   Round 7/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9854
#   Round 8/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9851
#   Round 9/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9859
#   Round 10/10
#     Client 6 failed authentication and is excluded.
#     Client 12 failed authentication and is excluded.
#     Client 33 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 37 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9860
#
# Running experiment for 75 clients...
#   Round 1/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9843
#   Round 2/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9841
#   Round 3/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9842
#   Round 4/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9841
#   Round 5/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9845
#   Round 6/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9838
#   Round 7/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9838
#   Round 8/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9841
#   Round 9/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9833
#   Round 10/10
#     Client 11 failed authentication and is excluded.
#     Client 27 failed authentication and is excluded.
#     Client 39 failed authentication and is excluded.
#     Client 57 failed authentication and is excluded.
#     Client 58 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9841
#
# Running experiment for 100 clients...
#   Round 1/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9782
#   Round 2/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9787
#   Round 3/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9787
#   Round 4/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9787
#   Round 5/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9783
#   Round 6/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9783
#   Round 7/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9785
#   Round 8/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9787
#   Round 9/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9794
#   Round 10/10
#     Client 3 failed authentication and is excluded.
#     Client 21 failed authentication and is excluded.
#     Client 66 failed authentication and is excluded.
#     Client 81 failed authentication and is excluded.
#     Client 86 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9789
#
# Experiment Results:
# Clients: 10, Avg Global Accuracy: 0.76317, Avg Local Accuracy: 0.40130, Avg Train Time: 0.37431s, Avg Auth Time: 0.00004s, Avg Round Latency: 2.47344s, Avg Aggregation Time: 0.01822s, Avg Comm Overhead: 3.36713MB, Global Model Size: 0.46762MB
# Clients: 25, Avg Global Accuracy: 0.98305, Avg Local Accuracy: 0.39880, Avg Train Time: 0.23614s, Avg Auth Time: 0.00008s, Avg Round Latency: 7.22970s, Avg Aggregation Time: 0.06340s, Avg Comm Overhead: 10.33317MB, Global Model Size: 0.46499MB
# Clients: 50, Avg Global Accuracy: 0.98578, Avg Local Accuracy: 0.39505, Avg Train Time: 0.17131s, Avg Auth Time: 0.00006s, Avg Round Latency: 13.76775s, Avg Aggregation Time: 0.13804s, Avg Comm Overhead: 21.89423MB, Global Model Size: 0.46348MB
# Clients: 75, Avg Global Accuracy: 0.98403, Avg Local Accuracy: 0.39215, Avg Train Time: 0.13639s, Avg Auth Time: 0.00007s, Avg Round Latency: 19.23402s, Avg Aggregation Time: 0.20905s, Avg Comm Overhead: 33.23410MB, Global Model Size: 0.46027MB
# Clients: 100, Avg Global Accuracy: 0.97863, Avg Local Accuracy: 0.38935, Avg Train Time: 0.10513s, Avg Auth Time: 0.00006s, Avg Round Latency: 22.43354s, Avg Aggregation Time: 0.26735s, Avg Comm Overhead: 38.59574MB, Global Model Size: 0.38646MB

# %% [markdown]
# **5. Experiments with Epsilon 1.5**

# %%
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lightgbm as lgb
import pickle
import os
import random

# Step 1: Load and preprocess the data
df = pd.read_csv('/content/drive/MyDrive/IDS-IOT2024/Process_1 IDS-IoT-2024.csv')

# Drop the target variable and assign features to X
X = df.iloc[:, :-1].values
y = df['Attack_Category_x'].values

# Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets for global evaluation
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Experiment setup
client_counts = [10, 25, 50, 75, 100]  # Number of clients to test
rounds = 10  # Number of federated learning rounds
privacy_budget = 1.5  # Privacy budget (epsilon)
results = []  # To store evaluation results for each client count

# Shuffle training data for IID client simulation
shuffled_indices = np.random.permutation(len(X_train_full))
X_train_shuffled = X_train_full[shuffled_indices]
y_train_shuffled = y_train_full[shuffled_indices]

# Differential Privacy - Laplace Mechanism
def apply_laplace_noise(values, epsilon, sensitivity=1.0):
    scale = sensitivity / epsilon
    noise = np.random.laplace(0, scale, size=values.shape)
    return values + noise

# Schnorr Protocol for Authentication
class SchnorrProtocol:
    def __init__(self, p, g):
        self.p = p
        self.g = g
        self.private_key = np.random.randint(1, p)
        self.public_key = pow(g, self.private_key, p)

    def generate_commitment(self):
        self.r = np.random.randint(1, self.p)
        self.R = pow(self.g, self.r, self.p)
        return self.R

    def compute_response(self, challenge):
        self.s = (self.r + challenge * self.private_key) % (self.p - 1)
        return self.s

    def verify(self, R, s, public_key, challenge):
        lhs = pow(self.g, s, self.p)
        rhs = (R * pow(public_key, challenge, self.p)) % self.p
        return lhs == rhs

# Schnorr Parameters
p = 104729
g = 2

# LightGBM parameters
lgb_params = {
    'objective': 'multiclass',
    'num_class': len(np.unique(y_encoded)),
    'boosting_type': 'gbdt',
    'metric': 'multi_logloss',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'max_depth': -1,
    'verbosity': -1
}

# Robust Aggregation (Median Aggregation)
def robust_aggregation(updates):
    """Aggregate model updates using a robust method like median aggregation."""
    return np.median(updates, axis=0)

# Experiment loop
for client_count in client_counts:
    print(f"\nRunning experiment for {client_count} clients...")

    # Step 1: Simulate clients
    client_data = []
    samples_per_client = len(X_train_shuffled) // client_count

    for i in range(client_count):
        start_idx = i * samples_per_client
        end_idx = start_idx + samples_per_client if i < client_count - 1 else len(X_train_shuffled)
        X_client = X_train_shuffled[start_idx:end_idx]
        y_client = y_train_shuffled[start_idx:end_idx]
        client_data.append((X_client, y_client))

    # Randomly assign poisoned clients
    num_data_poisoning_clients = min(2, client_count)
    num_model_poisoning_clients = min(3, client_count)
    data_poisoning_clients = random.sample(range(client_count), num_data_poisoning_clients)
    model_poisoning_clients = random.sample(
        [client for client in range(client_count) if client not in data_poisoning_clients],
        num_model_poisoning_clients,
    )

    # Reset performance tracking for the current experiment
    excluded_clients = 0
    local_accuracies = []
    global_accuracies = []
    client_auth_times = []
    client_train_times = []
    round_latencies = []
    aggregation_times = []
    communication_overheads = []

    # Reinitialize Schnorr protocols for the current number of clients
    client_protocols = [SchnorrProtocol(p, g) for _ in range(client_count)]

    # Step 2: Federated rounds
    for round_num in range(rounds):
        print(f"  Round {round_num + 1}/{rounds}")
        round_start_time = time.time()

        local_models = []
        local_predictions = []
        round_client_auth_times = []
        round_client_train_times = []
        round_comm_overhead = 0

        for client_num, (X_client, y_client) in enumerate(client_data):
            auth_start_time = time.time()
            schnorr = client_protocols[client_num]
            R = schnorr.generate_commitment()
            challenge = np.random.randint(1, p)

            # Simulate poisoning in response
            if client_num in data_poisoning_clients + model_poisoning_clients:
                response = schnorr.compute_response(challenge) + 1
            else:
                response = schnorr.compute_response(challenge)

            if not schnorr.verify(R, response, schnorr.public_key, challenge):
                print(f"    Client {client_num + 1} failed authentication and is excluded.")
                excluded_clients += 1
                continue
            auth_end_time = time.time()

            train_start_time = time.time()
            if client_num in data_poisoning_clients:
                print(f"    Simulating data poisoning on Client {client_num + 1}")
                X_client += np.random.normal(0, 0.5, X_client.shape)

            # Train local model
            train_data = lgb.Dataset(X_client, label=y_client)
            local_model = lgb.train(lgb_params, train_data, num_boost_round=20)

            if client_num in model_poisoning_clients:
                print(f"    Simulating model poisoning on Client {client_num + 1}")
                local_model.params['num_leaves'] += 5

            train_end_time = time.time()
            round_client_auth_times.append(auth_end_time - auth_start_time)
            round_client_train_times.append(train_end_time - train_start_time)

            local_model_bytes = pickle.dumps(local_model)
            round_comm_overhead += len(local_model_bytes)

            local_models.append(local_model)
            predictions = local_model.predict(X_test)
            noisy_predictions = apply_laplace_noise(predictions, epsilon=privacy_budget, sensitivity=1.0)
            local_predictions.append(noisy_predictions)

            local_pred = np.argmax(noisy_predictions, axis=1)
            local_accuracy = accuracy_score(y_test, local_pred)
            local_accuracies.append(local_accuracy)

        if local_predictions:
            aggregation_start_time = time.time()
            aggregated_predictions = robust_aggregation(local_predictions)
            y_pred_aggregated = np.argmax(aggregated_predictions, axis=1)
            global_accuracy = accuracy_score(y_test, y_pred_aggregated)
            global_accuracies.append(global_accuracy)
            aggregation_end_time = time.time()
            aggregation_times.append(aggregation_end_time - aggregation_start_time)

            aggregated_model_bytes = pickle.dumps(aggregated_predictions)
            round_comm_overhead += len(aggregated_model_bytes)

        communication_overheads.append(round_comm_overhead)
        round_latencies.append(time.time() - round_start_time)
        client_auth_times.extend(round_client_auth_times)
        client_train_times.extend(round_client_train_times)

        print(f"  Round {round_num + 1} completed with Global Accuracy: {global_accuracy:.4f}")

    # Save global model
    with open(f"global_model_{client_count}.pkl", "wb") as f:
        pickle.dump(local_models[0], f)

    global_model_size = os.path.getsize(f"global_model_{client_count}.pkl") / (1024 ** 2)  # in MB
    results.append({
        'clients': client_count,
        'avg_global_accuracy': np.mean(global_accuracies),
        'avg_local_accuracy': np.mean(local_accuracies),
        'avg_train_time': np.mean(client_train_times),
        'avg_auth_time': np.mean(client_auth_times),
        'avg_round_latency': np.mean(round_latencies),
        'avg_aggregation_time': np.mean(aggregation_times),
        'avg_comm_overhead': np.mean(communication_overheads) / (1024 ** 2),
        'global_model_size': global_model_size,
    })

# Print all results
print("\nExperiment Results:")
for result in results:
    print(f"Clients: {result['clients']}, "
          f"Avg Global Accuracy: {result['avg_global_accuracy']:.5f}, "
          f"Avg Local Accuracy: {result['avg_local_accuracy']:.5f}, "
          f"Avg Train Time: {result['avg_train_time']:.5f}s, "
          f"Avg Auth Time: {result['avg_auth_time']:.5f}s, "
          f"Avg Round Latency: {result['avg_round_latency']:.5f}s, "
          f"Avg Aggregation Time: {result['avg_aggregation_time']:.5f}s, "
          f"Avg Comm Overhead: {result['avg_comm_overhead']:.5f}MB, "
          f"Global Model Size: {result['global_model_size']:.5f}MB")
# Out:
# Running experiment for 10 clients...
#   Round 1/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.8275
#   Round 2/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.8252
#   Round 3/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.8286
#   Round 4/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.8272
#   Round 5/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.8283
#   Round 6/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.8303
#   Round 7/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.8273
#   Round 8/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.8228
#   Round 9/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.8222
#   Round 10/10
#     Client 1 failed authentication and is excluded.
#     Client 3 failed authentication and is excluded.
#     Client 7 failed authentication and is excluded.
#     Client 9 failed authentication and is excluded.
#     Client 10 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.8289
#
# Running experiment for 25 clients...
#   Round 1/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9875
#   Round 2/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9868
#   Round 3/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9872
#   Round 4/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9873
#   Round 5/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9875
#   Round 6/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9862
#   Round 7/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9863
#   Round 8/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9867
#   Round 9/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9873
#   Round 10/10
#     Client 2 failed authentication and is excluded.
#     Client 8 failed authentication and is excluded.
#     Client 14 failed authentication and is excluded.
#     Client 15 failed authentication and is excluded.
#     Client 19 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9871
#
# Running experiment for 50 clients...
#   Round 1/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9867
#   Round 2/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9861
#   Round 3/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9867
#   Round 4/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9869
#   Round 5/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9864
#   Round 6/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9866
#   Round 7/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9867
#   Round 8/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9870
#   Round 9/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9862
#   Round 10/10
#     Client 4 failed authentication and is excluded.
#     Client 20 failed authentication and is excluded.
#     Client 29 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 35 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9864
#
# Running experiment for 75 clients...
#   Round 1/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9841
#   Round 2/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9843
#   Round 3/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9849
#   Round 4/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9848
#   Round 5/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9844
#   Round 6/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9844
#   Round 7/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9843
#   Round 8/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9838
#   Round 9/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9840
#   Round 10/10
#     Client 3 failed authentication and is excluded.
#     Client 13 failed authentication and is excluded.
#     Client 17 failed authentication and is excluded.
#     Client 65 failed authentication and is excluded.
#     Client 67 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9848
#
# Running experiment for 100 clients...
#   Round 1/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 1 completed with Global Accuracy: 0.9796
#   Round 2/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 2 completed with Global Accuracy: 0.9797
#   Round 3/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 3 completed with Global Accuracy: 0.9800
#   Round 4/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 4 completed with Global Accuracy: 0.9788
#   Round 5/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 5 completed with Global Accuracy: 0.9793
#   Round 6/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 6 completed with Global Accuracy: 0.9793
#   Round 7/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 7 completed with Global Accuracy: 0.9799
#   Round 8/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 8 completed with Global Accuracy: 0.9793
#   Round 9/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 9 completed with Global Accuracy: 0.9795
#   Round 10/10
#     Client 12 failed authentication and is excluded.
#     Client 22 failed authentication and is excluded.
#     Client 34 failed authentication and is excluded.
#     Client 56 failed authentication and is excluded.
#     Client 74 failed authentication and is excluded.
#   Round 10 completed with Global Accuracy: 0.9795
#
# Experiment Results:
# Clients: 10, Avg Global Accuracy: 0.82683, Avg Local Accuracy: 0.44963, Avg Train Time: 0.37988s, Avg Auth Time: 0.00005s, Avg Round Latency: 2.52492s, Avg Aggregation Time: 0.01718s, Avg Comm Overhead: 3.36562MB, Global Model Size: 0.46688MB
# Clients: 25, Avg Global Accuracy: 0.98700, Avg Local Accuracy: 0.44611, Avg Train Time: 0.23702s, Avg Auth Time: 0.00005s, Avg Round Latency: 7.24665s, Avg Aggregation Time: 0.07007s, Avg Comm Overhead: 10.33576MB, Global Model Size: 0.46505MB
# Clients: 50, Avg Global Accuracy: 0.98657, Avg Local Accuracy: 0.44176, Avg Train Time: 0.17630s, Avg Auth Time: 0.00005s, Avg Round Latency: 13.97843s, Avg Aggregation Time: 0.14821s, Avg Comm Overhead: 21.89499MB, Global Model Size: 0.46368MB
# Clients: 75, Avg Global Accuracy: 0.98437, Avg Local Accuracy: 0.43811, Avg Train Time: 0.13814s, Avg Auth Time: 0.00006s, Avg Round Latency: 19.24896s, Avg Aggregation Time: 0.20972s, Avg Comm Overhead: 33.24038MB, Global Model Size: 0.45965MB
# Clients: 100, Avg Global Accuracy: 0.97948, Avg Local Accuracy: 0.43532, Avg Train Time: 0.10653s, Avg Auth Time: 0.00006s, Avg Round Latency: 22.62767s, Avg Aggregation Time: 0.27544s, Avg Comm Overhead: 38.59828MB, Global Model Size: 0.38432MB
